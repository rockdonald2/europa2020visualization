# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_json('../data/europa-data.json', orient='index')

# %%
fig, axis = plt.subplots(ncols=1, nrows=1, figsize=(16, 4))

df.loc['BE'][['ge_2015', 'ge_2016', 'ge_2017', 'ge_2018']].plot(kind='line', grid=True, ax=axis)
target = df.loc['BE']['ge_t']
temp = pd.Series(target, index=['ge_2015', 'ge_2016', 'ge_2017', 'ge_2018'])
temp.plot(kind='line', ax=axis, grid=True)

# %%
df
# Out:
#     e_2015  e_2016  e_2017  e_2018  e_2019   e_t  rd_2015  rd_2016  rd_2017  \
# BE    67.2    67.7    68.5    69.7    70.5  73.2     2.43     2.52     2.66
# BG    67.1    67.7    71.3    72.4    75.0  76.0     0.95     0.77     0.74
# CZ    74.8    76.7    78.5    79.9    80.3  75.0     1.93     1.68     1.79
# DK    75.4    76.0    76.6    77.5    78.3  80.0     3.06     3.09     3.05
# DE    78.0    78.6    79.2    79.9    80.6  77.0     2.93     2.94     3.07
# EE    76.5    76.6    78.7    79.5    80.2  76.0     1.46     1.25     1.28
# IE    69.9    71.4    73.0    74.1    75.1  69.0     1.18     1.17     1.24
# EL    54.9    56.2    57.8    59.5    61.2  70.0     0.96     0.99     1.13
# ES    62.0    63.9    65.5    67.0    68.0  74.0     1.22     1.19     1.21
# FR    69.5    70.0    70.6    71.3    71.6  75.0     2.27     2.22     2.21
# HR    60.6    61.4    63.6    65.2    66.7  62.9     0.84     0.86     0.86
# ...

# %%
# leírtam jegyzetbe, amit szeretnék ábrázolni
